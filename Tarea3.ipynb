# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/d/db/Logo_ITESO_normal.jpg" width="300" height="500" />
#
#
# ### Simulación de procesos financieros.
#
# **Nombres:**
#
# Estudiante 1: Héctor Josué Falomir Patrón
#
# Estudiante 2: Arturo Espinosa Carabez.
#
# **Fecha:** 10 de febrero del 2024.
#
# **Expediente** : `[7530461, 724189]
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/hectorfalomir/ProyectoConjunto_AEspinosa_JHFalomir
#
# # Tarea 3: Clase 6

# %% [markdown]
# > ## Tarea 3: (Usando notebook de jupyter)**
#
# > Usando compresión de listas o funciones map(sino recuerda como funciona observar el siguiente enlace https://www.pythonforbeginners.com/lists/list-comprehensions-in-python/), resolver los siguientes ejercicios:
#
# >1. Resolver la siguiente ecuación recursiva usando funciones como se vió en clase
# $$ D_{n}=(n-1) D_{n-1}+(n-1) D_{n-2} \quad n\ge 3$$
# con $D_1=0$ y $D_2 = 1$
# >3. Count the number of spaces in the following string `variable =  relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores`.
# >4. Remove all of the vowels in a string [make a list of the non-vowels].
# >5. Find all of the words in a string that are less than 4 letters.
# >6. Use a dictionary comprehension to count the length of each word in a sentence.
# >7. Use a nested list comprehension to find all of the numbers from 1-1000 that are divisible by any single digit besides 1 (2-9).

# %% [markdown]
# Código de solución estudiante 1

# %%
# 1
def D(n):
    if n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return (n - 1) * D(n - 1) + (n - 1) * D(n - 2)
    
def D_dynamic(n):
    if n == 1:
        return 0
    elif n == 2:
        return 1
    
    # Creamos una lista para almacenar los valores calculados
    dp = [0] * (n + 1)
    dp[1] = 0
    dp[2] = 1
    
    for i in range(3, n + 1):
        dp[i] = (i - 1) * dp[i - 1] + (i - 1) * dp[i - 2]
    
    return dp[n]
    
import time

start = time.time()
print(D(35))
end = time.time()
print(f'Tiempor de ejecución normal: {end-start} segundos')

start = time.time()
print(D_dynamic(35))
end = time.time()
print(f'Tiempo de ejecución dinámico: {end-start} segundos')
# Out:
# 3801352699415960663618057913952878940514
# Tiempor de ejecución normal: 6.076724529266357 segundos
# 3801352699415960663618057913952878940514
# Tiempo de ejecución dinámico: 0.0 segundos

# %% [markdown]
# Estudiante 2 Ej. 1

# %%
def funcion(n):
    if n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return (n - 1) * funcion(n - 1) + (n - 1) * funcion(n - 2)
n = 10  
secuencia = [funcion(i) for i in range(1, n + 1)]
secuencia
# Out:
# [0, 1, 2, 9, 44, 265, 1854, 14833, 133496, 1334961]

# %%
# 2
variable =  'relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores'

variable.count(' ')
# Out:
# 23

# %% [markdown]
# Estudiante 2 Ej. 2

# %%
word = "relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores."
space = 0
for char in word:
    if char == " ":
        space += 1
print("Number of spaces:", space)
# Out:
# Number of spaces: 23

# %%
# 3
vowels = 'aeiouAEIOUáéíóúÁÉÍÓÚ'

not_vowels = ''.join(map(lambda x: x if x not in vowels else '', variable))
print(not_vowels)
# Out:
# rlcnn  rqr,  pr btnr  l  vlr  d n  crt  trmn,  l cncmnt d ls ds ntrrs

# %% [markdown]
# Estudiante 2 Ej. 3

# %%
word = "relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores."
vowels2 = "aeiouAEIOU ,."
nonv2 = [char for char in word if char not in vowels2]
non_vowels_string = ''.join(nonv2)

nonv2
# Out:
# ['r',
#  'l',
#  'c',
#  'ó',
#  'n',
#  'n',
#  'r',
#  'q',
#  'r',
#  'p',
#  'r',
#  'b',
#  't',
#  'n',
#  'r',
#  'l',
#  'v',
#  'l',
#  'r',
#  'd',
#  'n',
#  'c',
#  'r',
#  't',
#  't',
#  'é',
#  'r',
#  'm',
#  'n',
#  'l',
#  'c',
#  'n',
#  'c',
#  'm',
#  'n',
#  't',
#  'd',
#  'l',
#  's',
#  'd',
#  's',
#  'n',
#  't',
#  'r',
#  'r',
#  's']

# %%
# 4
palabras_menos_de_4_letras = [palabra for palabra in variable.split() if len(palabra) < 4]
print(palabras_menos_de_4_letras)
# Out:
# ['el', 'de', 'un', 'el', 'de', 'los', 'dos']

# %% [markdown]
# Estudiante 2 Ej. 4

# %%
wordss = word.split()
short_words = [word for word in wordss if len(word) < 4]
short_words
# Out:
# ['el', 'de', 'un', 'el', 'de', 'los', 'dos']

# %%
# 5
longitudes_palabras = {palabra: len(palabra) for palabra in variable.split()}
print(f"Longitudes de las palabras:\n{longitudes_palabras}")
# Out:
# Longitudes de las palabras:
# {'relaciónn': 9, 'requiere,': 9, 'para': 4, 'obtener': 7, 'el': 2, 'valor': 5, 'de': 2, 'un': 2, 'cierto': 6, 'término,': 8, 'conocimiento': 12, 'los': 3, 'dos': 3, 'anteriores': 10}

# %% [markdown]
# Estudiante 2 Ej. 5

# %%
dictionary = {word: len(word) for word in wordss}
dictionary
# Out:
# {'relaciónn': 9,
#  'requiere,': 9,
#  'para': 4,
#  'obtener': 7,
#  'el': 2,
#  'valor': 5,
#  'de': 2,
#  'un': 2,
#  'cierto': 6,
#  'término,': 8,
#  'conocimiento': 12,
#  'los': 3,
#  'dos': 3,
#  'anteriores.': 11}

# %%
# 6 
numeros_divisible = [num for num in range(1, 1001) if any(num % digit == 0 for digit in range(2, 10))]
print(numeros_divisible)
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 14, 15, 16, 18, 20, 21, 22, 24, 25, 26, 27, 28, 30, 32, 33, 34, 35, 36, 38, 39, 40, 42, 44, 45, 46, 48, 49, 50, 51, 52, 54, 55, 56, 57, 58, 60, 62, 63, 64, 65, 66, 68, 69, 70, 72, 74, 75, 76, 77, 78, 80, 81, 82, 84, 85, 86, 87, 88, 90, 91, 92, 93, 94, 95, 96, 98, 99, 100, 102, 104, 105, 106, 108, 110, 111, 112, 114, 115, 116, 117, 118, 119, 120, 122, 123, 124, 125, 126, 128, 129, 130, 132, 133, 134, 135, 136, 138, 140, 141, 142, 144, 145, 146, 147, 148, 150, 152, 153, 154, 155, 156, 158, 159, 160, 161, 162, 164, 165, 166, 168, 170, 171, 172, 174, 175, 176, 177, 178, 180, 182, 183, 184, 185, 186, 188, 189, 190, 192, 194, 195, 196, 198, 200, 201, 202, 203, 204, 205, 206, 207, 208, 210, 212, 213, 214, 215, 216, 217, 218, 219, 220, 222, 224, 225, 226, 228, 230, 231, 232, 234, 235, 236, 237, 238, 240, 242, 243, 244, 245, 246, 248, 249, 250, 252, 254, 255, 256, 258, 259, 260, 261, 262, 264, 265, 266, 267, 268, 270, 272, 273, 274, 275, 276, 278, 279, 280, 28
# ...

# %% [markdown]
# Estudiante 2 Ej. 6

# %%
divisibles = [num for num in range(1, 1001) if any(num % i == 0 for i in range(2, 10))]
divisibles
# Out:
# [2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  9,
#  10,
#  12,
#  14,
#  15,
#  16,
#  18,
#  20,
#  21,
#  22,
#  24,
#  25,
#  26,
#  27,
#  28,
#  30,
#  32,
#  33,
#  34,
#  35,
#  36,
#  38,
#  39,
#  40,
#  42,
#  44,
#  45,
#  46,
#  48,
#  49,
#  50,
#  51,
#  52,
#  54,
#  55,
#  56,
#  57,
#  58,
#  60,
#  62,
#  63,
#  64,
#  65,
#  66,
#  68,
#  69,
#  70,
#  72,
#  74,
#  75,
#  76,
#  77,
#  78,
#  80,
#  81,
#  82,
#  84,
#  85,
#  86,
#  87,
#  88,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  98,
#  99,
#  100,
#  102,
#  104,
#  105,
#  106,
#  108,
#  110,
#  111,
#  112,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  122,
#  123,
#  124,
#  125,
#  126,
#  128,
#  129,
#  130,
#  132,
#  133,
#  134,
#  135,
#  136,
#  138,
#  140,
#  141,
#  142,
#  144,
#  145,
#  146,
#  147,
#  148,
#  150,
#  152,
#  153,
#  154,
#  155,
#  156,
#  158,
#  159,
#  160,
#  161,
#  162,
#  164,
#  165,
#  166,
#  168,
#  170,
#  171,
#  172,
#  174,
#  175,
# ...
